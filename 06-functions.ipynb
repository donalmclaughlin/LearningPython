# %%
def fahr_to_celsius(temp):
    return ((temp-32)*5/9)

# %%
fahr_to_celsius(32)
# Out:
# 0.0

# %%
5 + fahr_to_celsius(32)
# Out:
# 5.0

# %%
print("Boiling temp of water: ", fahr_to_celsius(212))
# Out:
# Boiling temp of water:  100.0

# %%
def celsius_to_kelvin(temp_c):
    return (temp_c+273.15)

# %%
celsius_to_kelvin(10)
# Out:
# 283.15

# %%
def fahr_to_kelvin(temp_f):
    temp_c = fahr_to_celsius(temp_f)
    temp_k = celsius_to_kelvin(temp_c)
    return temp_k

# %%
fahr_to_kelvin(32)
# Out:
# 273.15

# %%
def visualise(filename):
    data = numpy.loadtxt(fname=filename, delimiter=',')
    fig = matplotlib.pyplot.figure(figsize=(10,3))
    axes1 = fig.add_subplot(1,3,1)
    axes2 = fig.add_subplot(1,3,2)
    axes3 = fig.add_subplot(1,3,3)

    axes1.set_ylabel('average')
    axes1.plot(data.mean(axis=0))

    axes2.set_ylabel('max')
    axes2.plot(data.max(axis=0))

    axes3.set_ylabel('min')
    axes3.set_ylim(0,6)
    axes3.plot(data.min(axis=0))

    fig.tight_layout()
    matplotlib.pyplot.show()

# %%
def detect_problems(filename):
    data = numpy.loadtxt(fname=filename, delimiter=',')
    if data.max(axis=0)[0]==0 and data.max(axis=0)[20] == 20:
        print("suspicious looking maxima")
    elif data.min(axis=0).sum() == 0:
        print("minima add up to zero.")
    else:
        print("seems ok")

# %%
# %matplotlib inline

# %%
import glob
import numpy
import matplotlib

# %%
filenames = sorted(glob.glob('data/inflammation*.csv'))

for f in filenames[:3]:
    print(f)
    visualise(f)
    detect_problems(f)
# Out:
# data\inflammation-01.csv
# suspicious looking maxima
# data\inflammation-02.csv
# suspicious looking maxima
# data\inflammation-03.csv
# minima add up to zero.

# %%
def offset_mean(data, target_mean_value):
    """ This is my function that offsets.
    Example: offset_mean([1,2,3],0)=> [-1,0,1]
    """
    return (data-numpy.mean(data)) + target_mean_value

# %%
z = numpy.zeros((2,2))
print(offset_mean(z,3))
# Out:
# [[3. 3.]
#  [3. 3.]]

# %%
filenames = sorted(glob.glob('data/inflammation*.csv'))
filename = filenames[0]
data = numpy.loadtxt(fname=filename, delimiter=',')

print("original min, mean, max: ", numpy.min(data), numpy.mean(data), numpy.max(data))
offset_data = offset_mean(data, 0.0)
print("offset min, mean, max: ", numpy.min(offset_data), numpy.mean(offset_data), numpy.max(offset_data))
# Out:
# original min, mean, max:  0.0 6.14875 20.0
# offset min, mean, max:  -6.14875 2.842170943040401e-16 13.85125

# %%
print("standard dev before: ", numpy.std(data))
print("standard dev after: ", numpy.std(offset_data))
# Out:
# standard dev before:  4.613833197118566
# standard dev after:  4.613833197118566

# %%
print("Diff in std dev: ", numpy.std(data)-numpy.std(offset_data))
# Out:
# Diff in std dev:  0.0

# %%
help(offset_mean)
# Out:
# Help on function offset_mean in module __main__:
#
# offset_mean(data, target_mean_value)
#     This is my function that offsets.

# %%
def offset_mean(data, target_mean_value=0.0):
    """ This is my function that offsets.
    Example: offset_mean([1,2,3],0)=> [-1,0,1]
    """
    return (data-numpy.mean(data)) + target_mean_value

# %%
offset_mean([1,2,3],0)
# Out:
# array([-1.,  0.,  1.])

# %%
offset_mean([1,2,3])
# Out:
# array([-1.,  0.,  1.])

# %%
offset_mean([1,2,3],10)
# Out:
# array([ 9., 10., 11.])

# %%
def display(a=1, b=2, c=3):
    print("a:", a, "b:", b, "c:", c)

# %%
display(100, 200, 300)
# Out:
# a: 100 b: 200 c: 300

# %%
display()
# Out:
# a: 1 b: 2 c: 3
